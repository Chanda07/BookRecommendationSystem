# %%
#Import required libraries
import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import confusion_matrix, plot_confusion_matrix
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Extraction of data from the csv files
df=pd.read_csv("books.csv")

#Read first ten records from the files
df.head(10)
# Out:
#    id   book_id  best_book_id   work_id  books_count             authors  \
# 0   1   2767052       2767052   2792775          272     Suzanne Collins
# 1   2         3             3   4640799          491          JK Rowling
# 2   3     41865         41865   3212258          226     Stephenie Meyer
# 3   4      2657          2657   3275794          487          Harper Lee
# 4   5      4671          4671    245494         1356  F Scott Fitzgerald
# 5   6  11870085      11870085  16827462          226          John Green
# 6   7      5907          5907   1540236          969         JRR Tolkien
# 7   8      5107          5107   3036731          360         JD Salinger
# 8   9       960           960   3338963          311           Dan Brown
# 9  10      1885          1885   3060926         3455         Jane Austen
#
#    original_publication_year                            original_title  \
# 0                     2008.0                          The Hunger Games
# ...

# %%
df
# Out:
#          id  book_id  best_book_id   work_id  books_count             authors  \
# 0         1  2767052       2767052   2792775          272     Suzanne Collins
# 1         2        3             3   4640799          491          JK Rowling
# 2         3    41865         41865   3212258          226     Stephenie Meyer
# 3         4     2657          2657   3275794          487          Harper Lee
# 4         5     4671          4671    245494         1356  F Scott Fitzgerald
# ...     ...      ...           ...       ...          ...                 ...
# 9994   9996  7130616       7130616   7392860           19       Ilona Andrews
# 9995   9997   208324        208324   1084709           19       Robert A Caro
# 9996   9998    77431         77431   2393986           60     Patrick O'Brian
# 9997   9999  8565083       8565083  13433613            7     Peggy Orenstein
# 9998  10000     8914          8914     11817           31         John Keegan
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 40 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         9999 non-null   int64
#  1   book_id                    9999 non-null   int64
#  2   best_book_id               9999 non-null   int64
#  3   work_id                    9999 non-null   int64
#  4   books_count                9999 non-null   int64
#  5   authors                    9999 non-null   object
#  6   original_publication_year  9978 non-null   float64
#  7   original_title             9414 non-null   object
#  8   title                      9999 non-null   object
#  9   language_code              8915 non-null   object
#  10  average_rating             9999 non-null   float64
#  11  ratings_count              9999 non-null   int64
#  12  work_ratings_count         9999 non-null   int64
# ...

# %%
df = df.replace(r'^\s*$', np.nan, regex=True)

# %%
df.average_rating.value_counts()
# Out:
# 3.94    187
# 3.98    180
# 4.16    178
# 4.07    173
# 4.04    173
#        ...
# 3.01      1
# 4.64      1
# 3.11      1
# 2.47      1
# 3.09      1
# Name: average_rating, Length: 184, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

LE = LabelEncoder()

# %%
df['Record'] = LE.fit_transform(df['title'])

# %%
df
# Out:
#          id  book_id  best_book_id   work_id  books_count             authors  \
# 0         1  2767052       2767052   2792775          272     Suzanne Collins
# 1         2        3             3   4640799          491          JK Rowling
# 2         3    41865         41865   3212258          226     Stephenie Meyer
# 3         4     2657          2657   3275794          487          Harper Lee
# 4         5     4671          4671    245494         1356  F Scott Fitzgerald
# ...     ...      ...           ...       ...          ...                 ...
# 9994   9996  7130616       7130616   7392860           19       Ilona Andrews
# 9995   9997   208324        208324   1084709           19       Robert A Caro
# 9996   9998    77431         77431   2393986           60     Patrick O'Brian
# 9997   9999  8565083       8565083  13433613            7     Peggy Orenstein
# 9998  10000     8914          8914     11817           31         John Keegan
#
# ...

# %%
df = df.drop(columns=['image_url'])

# %%
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.utils import resample
zero = df[df.average_rating >=0 ]
one = df[df.average_rating >= 1]

# %%
len(zero)
# Out:
# 9999

# %%
df_final = resample(one, n_samples = len(zero))
df_Final = pd.concat([df_final,zero],axis = 0)

# %%
df_Final.average_rating.value_counts()
# Out:
# 4.16    376
# 3.94    365
# 4.05    356
# 3.98    350
# 4.07    349
#        ...
# 4.64      1
# 2.97      1
# 2.47      1
# 3.01      1
# 2.98      1
# Name: average_rating, Length: 184, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X = df_Final.drop(columns = ['average_rating'])
y = df_Final.average_rating
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size = 0.5, random_state = 42)

# %%
x_train.shape
# Out:
# (9999, 39)

# %%
cm_x = x_train[:1000]
cm_y = y_train[:1000]

# %%
from sklearn.ensemble import RandomForestClassifier
RFC = RandomForestClassifier()

# %%
model = RFC.fit(cm_x,cm_y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [571], in <cell line: 1>()
# ----> 1 model = RFC.fit(cm_x,cm_y)
#
# File D:\app folder\Anaconda\lib\site-packages\sklearn\ensemble\_forest.py:327, in BaseForest.fit(self, X, y, sample_weight)
#     325 if issparse(y):
#     326     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 327 X, y = self._validate_data(
#     328     X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     329 )
#     330 if sample_weight is not None:
#     331     sample_weight = _check_sample_weight(sample_weight, X)
#
# File D:\app folder\Anaconda\lib\site-packages\sklearn\base.py:581, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     579         y = check_array(y, **check_y_params)
#     580     else:
# --> 581         X, y = check_X_y(X, y, **check_params)
# ...

# %%
y_pred = model.predict(x_test)
